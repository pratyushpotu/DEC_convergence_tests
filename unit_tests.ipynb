# %%
import tests.test_derivatives as td
import tests.test_geometry as tg
import tests.test_hodge as th
import tests.test_integrators as ti
import tests.test_mesh as tm

# %%
td.run_all_tests_derivatives()
# Out:
# All Derivative tests passed.

# %%
tg.run_all_tests_geometry()
# Out:
# All Geometry tests passed.

# %%
th.run_all_tests_hodge()
# Out:
# All Hodge star tests passed.

# %%
ti.run_all_tests_integrators()
# Out:
# All Integrator tests passed.

# %%
tm.run_all_tests_mesh()
# Out:
# All mesh tests passed.
